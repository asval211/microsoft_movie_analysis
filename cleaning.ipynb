# %%
import sqlite3
import pandas as pd 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
bom_movie_gross = pd.read_csv('data/zippedData/bom.movie_gross.csv.gz')
name_basics = pd.read_csv('data/zippedData/imdb.name.basics.csv.gz')
title = pd.read_csv('data/zippedData/imdb.title.akas.csv.gz')
title_crew = pd.read_csv('data/zippedData/imdb.title.crew.csv.gz')
title_principles = pd.read_csv('data/zippedData/imdb.title.principals.csv.gz')
title_ratings = pd.read_csv('data/zippedData/imdb.title.ratings.csv.gz')

# %%
print(len(bom_movie_gross))
bom_movie_gross.head()
# Out:
# 3387
#                                          title studio  domestic_gross  \
# 0                                  Toy Story 3     BV     415000000.0
# 1                   Alice in Wonderland (2010)     BV     334200000.0
# 2  Harry Potter and the Deathly Hallows Part 1     WB     296000000.0
# 3                                    Inception     WB     292600000.0
# 4                          Shrek Forever After   P/DW     238700000.0
#
#   foreign_gross  year
# 0     652000000  2010
# 1     691300000  2010
# 2     664300000  2010
# 3     535700000  2010
# 4     513900000  2010

# %%
bom_movie_gross['studio'].hist()
df = pd.DataFrame(
    np.random.randint(1, 7, 6000),
    columns = ['studio']['domestic_gross'])
df['domestic_gross'] = df['studio'] + np.random.randint(1, 7, 6000)
ax = df.plot.hist(bins=12, alpha=0.5)
# Out:
# <>:4: SyntaxWarning: list indices must be integers or slices, not str; perhaps you missed a comma?
# <>:4: SyntaxWarning: list indices must be integers or slices, not str; perhaps you missed a comma?
# <ipython-input-161-7361a3d74490>:4: SyntaxWarning: list indices must be integers or slices, not str; perhaps you missed a comma?
#   columns = ['studio']['domestic_gross'])
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-161-7361a3d74490> in <module>
#       2 df = pd.DataFrame(
#       3     np.random.randint(1, 7, 6000),
# ----> 4     columns = ['studio']['domestic_gross'])
#       5 df['domestic_gross'] = df['studio'] + np.random.randint(1, 7, 6000)
#       6 ax = df.plot.hist(bins=12, alpha=0.5)
#
# TypeError: list indices must be integers or slices, not str

# %%
ig, ax = plt.subplots(figsize=(10,8))


ax.bar('studio'.index, 'domestic_gross'.index)

# Add labels for x and y axes
ax.set_xlabel('Studio')
ax.set_ylabel('Domestic Gross')

# Add a title for the plot
ax.set_title('Most Common Last Names on Titanic', fontsize=15)


#ax.tick_params(axis='x', labelrotation = 45)

# add a legend
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\anaconda3\envs\learn-env\lib\site-packages\matplotlib\axes\_axes.py in bar(self, x, height, width, bottom, align, **kwargs)
#    2459                 try:
# -> 2460                     left = x - width / 2
#    2461                 except TypeError as e:
#
# TypeError: unsupported operand type(s) for -: 'builtin_function_or_method' and 'float'
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-214-68bb8b900c31> in <module>
#       2
#       3
# ----> 4 ax.bar('studio'.index, 'domestic_gross'.index)
#       5
#       6 # Add labels for x and y axes
#
# ~\anaconda3\envs\learn-env\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1436     def inner(ax, *args, data=None, **kwargs):
# ...

# %%
top10 = bom_movie_gross.value_counts().head(10)

# %%
#drop nulls and convert domestic_gross to integer
print(bom_studio_gross['foreign_gross'].isnull().sum())
print(bom_studio_gross['foreign_gross'].fillna(value=0, inplace=True))
print(bom_studio_gross['foreign_gross'].isnull().sum())
print(bom_studio_gross.head())
print(bom_studio_gross.foreign_gross)
print(bom_studio_gross['domestic_gross'].isnull().sum())
print(bom_studio_gross['domestic_gross'].dropna(inplace=True))
print(bom_studio_gross['domestic_gross'].isnull().sum())
print(bom['total_gross'] = bom['domestic_gross'] / bom['foreign_gross'])
# Out:
#   File "<ipython-input-143-82e39ee2020e>", line 10
#     print(bom['total_gross'] = bom['domestic_gross'] / bom['foreign_gross'])
#           ^
# SyntaxError: expression cannot contain assignment, perhaps you meant "=="?

# %%
query2 = pd.read_sql('''SELECT *
FROM rotten_tomatoes_movies 
ORDER BY audience_rating DESC 
''',conn)

# %%
query2['genres'].value_counts()
# Out:
# Drama                                                                                                             1887
# Comedy                                                                                                            1263
# Comedy, Drama                                                                                                      863
# Drama, Mystery & Suspense                                                                                          731
# Art House & International, Drama                                                                                   589
#                                                                                                                   ...
# Cult Movies, Musical & Performing Arts                                                                               1
# Action & Adventure, Animation, Kids & Family, Special Interest                                                       1
# ...

# %%
query2
# Out:
#          idx                     rotten_tomatoes_link  \
# 0        217                     m/10010692-ballerina
# 1       1329                           m/1103197-city
# 2       1848                     m/1219638-ice_people
# 3       2522                          m/all_i_can_say
# 4       2829  m/anthony_jeselnik_thoughts_and_prayers
# ...      ...                                      ...
# 17707  17522                     m/working_girls_1987
# 17708  17607                                m/yom_yom
# 17709  17609                          m/yosemite_2016
# 17710  17618       m/you_dont_need_feet_to_dance_2013
# 17711  17671                                 m/z_2019
#
#                                   movie_title  \
# 0                             Prima Ballerina
# 1                        La Ciudad (The City)
# 2                                  Ice People
# 3                               All I Can Say
# 4      Anthony Jeselnik: Thoughts and Prayers
# ...

# %%
query5 = pd.read_sql('''SELECT *, known_for_titles
FROM imdb_name_basics
JOIN imdb_title_principals USING (nconst)
JOIN imdb_title_crew USING (tconst)
JOIN imdb_title_ratings 

''',conn)

# %%
query5
