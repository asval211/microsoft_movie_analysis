# %%
import sqlite3
import pandas as pd 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
bom_movie_gross = pd.read_csv('data/zippedData/bom.movie_gross.csv.gz')
tmbd = pd.read_csv('data/zippedData/tmdb.movies.csv.gz')
title_crew = pd.read_csv('data/zippedData/imdb.title.crew.csv.gz')
name_basics = pd.read_csv('data/zippedData/imdb.name.basics.csv.gz')
title_p =pd.read_csv('data/zippedData/imdb.title.principals.csv.gz')
title_b =pd.read_csv('data/zippedData/imdb.title.basics.csv.gz')
movies =pd.read_csv('data/zippedData/tmdb.movies.csv.gz')
ratings = pd.read_csv('data/zippedData/imdb.title.ratings.csv.gz')
budget = pd.read_csv('data/zippedData/tn.movie_budgets.csv.gz')

# %%
title_crew.head(2)
# Out:
#       tconst  directors              writers
# 0  tt0285252  nm0899854            nm0899854
# 1  tt0438973        NaN  nm0175726,nm1802864

# %%
title_p.head(2)
# Out:
#       tconst  ordering     nconst  category  job   characters
# 0  tt0111414         1  nm0246005     actor  NaN  ["The Man"]
# 1  tt0111414         2  nm0398271  director  NaN          NaN

# %%
name_df = title_crew.merge(title_p, on='tconst').merge(name_basics, on='nconst')

# %%
name_df
# Out:
#             tconst  directors    writers  ordering      nconst  category  job  \
# 0        tt0285252  nm0899854  nm0899854        10   nm1077681  composer  NaN
# 1        tt0285252  nm0899854  nm0899854         1   nm0960950     actor  NaN
# 2        tt0285252  nm0899854  nm0899854         2   nm0461311     actor  NaN
# 3        tt0285252  nm0899854  nm0899854         3   nm0000686     actor  NaN
# 4        tt1931533  nm1732981  nm1732981         4   nm0000686     actor  NaN
# ...            ...        ...        ...       ...         ...       ...  ...
# 1027907  tt9004986  nm4993825  nm4993825         3   nm6450115     actor  NaN
# 1027908  tt9004986  nm4993825  nm4993825         4  nm10124716      self  NaN
# 1027909  tt9010172        NaN  nm8352242         1  nm10126917     actor  NaN
# 1027910  tt9010172        NaN  nm8352242         2   nm8352244     actor  NaN
# 1027911  tt9010172        NaN  nm8352242         3   nm8352242    writer  NaN
#
# ...

# %%
name_df
# Out:
#             tconst  directors    writers  ordering      nconst  category  job  \
# 0        tt0285252  nm0899854  nm0899854        10   nm1077681  composer  NaN
# 1        tt0285252  nm0899854  nm0899854         1   nm0960950     actor  NaN
# 2        tt0285252  nm0899854  nm0899854         2   nm0461311     actor  NaN
# 3        tt0285252  nm0899854  nm0899854         3   nm0000686     actor  NaN
# 4        tt1931533  nm1732981  nm1732981         4   nm0000686     actor  NaN
# ...            ...        ...        ...       ...         ...       ...  ...
# 1027907  tt9004986  nm4993825  nm4993825         3   nm6450115     actor  NaN
# 1027908  tt9004986  nm4993825  nm4993825         4  nm10124716      self  NaN
# 1027909  tt9010172        NaN  nm8352242         1  nm10126917     actor  NaN
# 1027910  tt9010172        NaN  nm8352242         2   nm8352244     actor  NaN
# 1027911  tt9010172        NaN  nm8352242         3   nm8352242    writer  NaN
#
# ...

# %%
ratings1 = title_b.merge(name_df, on='tconst')

# %%
ratings1
# Out:
#             tconst                   primary_title  \
# 0        tt0063540                       Sunghursh
# 1        tt0063540                       Sunghursh
# 2        tt0063540                       Sunghursh
# 3        tt0063540                       Sunghursh
# 4        tt0063540                       Sunghursh
# ...            ...                             ...
# 1027907  tt9916754  Chico Albuquerque - Revelações
# 1027908  tt9916754  Chico Albuquerque - Revelações
# 1027909  tt9916754  Chico Albuquerque - Revelações
# 1027910  tt9916754  Chico Albuquerque - Revelações
# 1027911  tt9916754  Chico Albuquerque - Revelações
#
#                          original_title  start_year  runtime_minutes  \
# 0                             Sunghursh        2013            175.0
# 1                             Sunghursh        2013            175.0
# 2                             Sunghursh        2013            175.0
# 3                             Sunghursh        2013            175.0
# ...

# %%
ratings1
# Out:
#             tconst                   primary_title  \
# 0        tt0063540                       Sunghursh
# 1        tt0063540                       Sunghursh
# 2        tt0063540                       Sunghursh
# 3        tt0063540                       Sunghursh
# 4        tt0063540                       Sunghursh
# ...            ...                             ...
# 1027907  tt9916754  Chico Albuquerque - Revelações
# 1027908  tt9916754  Chico Albuquerque - Revelações
# 1027909  tt9916754  Chico Albuquerque - Revelações
# 1027910  tt9916754  Chico Albuquerque - Revelações
# 1027911  tt9916754  Chico Albuquerque - Revelações
#
#                          original_title  start_year  runtime_minutes  \
# 0                             Sunghursh        2013            175.0
# 1                             Sunghursh        2013            175.0
# 2                             Sunghursh        2013            175.0
# 3                             Sunghursh        2013            175.0
# ...

# %%
ratings1 = ratings1[ratings1['genres'].notna()]
ratings1 = ratings1[ratings1['runtime_minutes'].notna()]
ratings1 = ratings1[ratings1['characters'].notna()]
ratings1 = ratings1[ratings1['death_year'].notna()]
ratings1 = ratings1[ratings1['writers'].notna()]
ratings1 = ratings1[ratings1['primary_profession'].notna()]

# %%
ratings1
# Out:
#             tconst                   primary_title  \
# 0        tt0063540                       Sunghursh
# 1        tt0063540                       Sunghursh
# 2        tt0063540                       Sunghursh
# 3        tt0063540                       Sunghursh
# 4        tt0063540                       Sunghursh
# ...            ...                             ...
# 1027907  tt9916754  Chico Albuquerque - Revelações
# 1027908  tt9916754  Chico Albuquerque - Revelações
# 1027909  tt9916754  Chico Albuquerque - Revelações
# 1027910  tt9916754  Chico Albuquerque - Revelações
# 1027911  tt9916754  Chico Albuquerque - Revelações
#
#                          original_title  start_year  runtime_minutes  \
# 0                             Sunghursh        2013            175.0
# 1                             Sunghursh        2013            175.0
# 2                             Sunghursh        2013            175.0
# 3                             Sunghursh        2013            175.0
# ...

# %%
ratings1.primary_profession.value_counts()
# Out:
# actor                                              126461
# actress                                             87277
# producer                                            31957
# composer                                            24108
# writer                                              22473
#                                                     ...
# assistant_director,music_department                     1
# sound_department,miscellaneous,art_department           1
# editor,producer,costume_designer                        1
# location_management,actress,art_director                1
# production_designer,producer,assistant_director         1
# Name: primary_profession, Length: 8631, dtype: int64

# %%
director_stats = ratings1.groupby('primary_profession').agg(['median','mean', ]).reset_index()

# %%
director_stats = director_stats.primary_profession.str.split(',')

# %%
director_stats = director_stats.explode('primary_profession')

# %%
director_stats
# Out:
# 0                       actor
# 1                       actor
# 2        animation_department
# 3                       actor
# 4        animation_department
#                  ...
# 25221          visual_effects
# 25222      production_manager
# 25223                  writer
# 25224          visual_effects
# 25225         special_effects
# Name: primary_profession, Length: 25226, dtype: object

# %%
ratings1['genres'].unique

# %%
ratings1['directors'].hist()
# Out:
# <AxesSubplot:>

# %%
plot.show
