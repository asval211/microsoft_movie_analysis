# %% [markdown]
# # Top 10 Actors/Actresses

# %% [markdown]
# # 1. Import Data

# %%
import sqlite3
import pandas as pd 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
bom_movie_gross = pd.read_csv('data/zippedData/bom.movie_gross.csv.gz')
tmbd = pd.read_csv('data/zippedData/tmdb.movies.csv.gz')
title_crew = pd.read_csv('data/zippedData/imdb.title.crew.csv.gz')
name_basics = pd.read_csv('data/zippedData/imdb.name.basics.csv.gz')
title_p =pd.read_csv('data/zippedData/imdb.title.principals.csv.gz')
title_b =pd.read_csv('data/zippedData/imdb.title.basics.csv.gz')
movies =pd.read_csv('data/zippedData/tmdb.movies.csv.gz')
ratings = pd.read_csv('data/zippedData/imdb.title.ratings.csv.gz')

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# Get the shape of data that is being used.

# %%
print(name_basics.shape)
print(title_p.shape)
# Out:
# (606648, 6)
# (1028186, 6)

# %% [markdown]
# Clean names from the dataframe.

# %%
name_basics['nconst'].isna().sum()
# Out:
# 0

# %% [markdown]
# Sort the name basics file.

# %%
name_basics = name_basics.sort_values(by=['primary_name'])

# %%
name_basics
# Out:
#             nconst                 primary_name  birth_year  death_year  \
# 334669   nm6950093  !'aru Ikhuisi Piet Berendse         NaN         NaN
# 480537   nm6750303                      $hutter         NaN         NaN
# 68747   nm10554376               'A.J.' Marriot         NaN         NaN
# 177430   nm2764095         'Atlas' Ramachandran         NaN         NaN
# 252452   nm5169037              'Atolomake Helu         NaN         NaN
# ...            ...                          ...         ...         ...
# 251954   nm4964487               Þórir Bragason         NaN         NaN
# 361353   nm8372002             Þórir Ingvarsson         NaN         NaN
# 93977   nm10211575           Þórunn Lárusdóttir         NaN         NaN
# 173454   nm1800527           Þórunn Lárusdóttir         NaN         NaN
# 490858   nm5232286         Þórður Aðalbjörnsson         NaN         NaN
#
#                       primary_profession  \
# 334669                               NaN
# 480537                             actor
# 68747               writer,miscellaneous
# 177430                    actor,director
# 252452                               NaN
# ...                                  ...
# 251954                          composer
# 361353  cinematographer,sound_department
# 93977                actor,writer,editor
# 173454                  actress,director
# 490858                             actor
#
#                                known_for_titles
# 334669                                tt4245110
# 480537  tt4049298,tt1398426,tt2080374,tt1741273
# 68747                                       NaN
# 177430  tt3433162,tt1311658,tt2333760,tt0928194
# 252452                                tt1966622
# ...                                         ...
# 251954                                tt2316669
# 361353                                tt5977838
# 93977                                 tt9174804
# 173454  tt9174804,tt5881406,tt0439436,tt1245694
# 490858                                tt2343384
#
# [606648 rows x 6 columns]

# %% [markdown]
# Find how many null values are in the dataframe.

# %%
name_basics['nconst'].isna().sum()
# Out:
# 0

# %% [markdown]
# Search for dupilcates.

# %%
names_dupes = name_basics.loc[name_basics.duplicated(subset=['primary_name'],keep=False) == True]
names_dupes
# Out:
#             nconst        primary_name  birth_year  death_year  \
# 129377  nm10275444        A. Venkatesh         NaN         NaN
# 387377   nm8956236        A. Venkatesh         NaN         NaN
# 279631   nm4062141        A. Venkatesh         NaN         NaN
# 156216   nm1701176        A. Venkatesh         NaN         NaN
# 30159    nm0451160           A.J. Khan      1977.0         NaN
# ...            ...                 ...         ...         ...
# 433984   nm6356309         Özgür Bakar         NaN         NaN
# 102820   nm2561272       Øystein Mamen         NaN         NaN
# 603769   nm8122779       Øystein Mamen         NaN         NaN
# 93977   nm10211575  Þórunn Lárusdóttir         NaN         NaN
# 173454   nm1800527  Þórunn Lárusdóttir         NaN         NaN
#
#                               primary_profession  \
# 129377                                  director
# 387377                                  producer
# 279631                     director,actor,writer
# 156216  cinematographer,camera_department,editor
# 30159        actress,make_up_department,director
# ...                                          ...
# 433984                  director,writer,producer
# 102820  cinematographer,camera_department,editor
# 603769                           cinematographer
# 93977                        actor,writer,editor
# 173454                          actress,director
#
#                                 known_for_titles
# 129377                                 tt9319898
# 387377                                 tt6834466
# 279631   tt4976496,tt6765648,tt4318038,tt6827080
# 156216   tt0984177,tt0327761,tt0072026,tt4160030
# 30159    tt0203536,tt1651142,tt0367014,tt0323108
# ...                                          ...
# 433984  tt4368072,tt10046236,tt7717990,tt4764942
# 102820   tt2713778,tt6275296,tt3541092,tt0966566
# 603769                                 tt2660730
# 93977                                  tt9174804
# 173454   tt9174804,tt5881406,tt0439436,tt1245694
#
# [50865 rows x 6 columns]

# %%
id_dupes = name_basics.loc[name_basics.duplicated(subset=['nconst'],keep=False) == True]
id_dupes
# Out:
# Empty DataFrame
# Columns: [nconst, primary_name, birth_year, death_year, primary_profession, known_for_titles]
# Index: []

# %% [markdown]
# Find the shapes of the name basics.

# %%
print(names_dupes.shape)
print(name_basics.shape)
print(50865/606648)
# Out:
# (50865, 6)
# (606648, 6)
# 0.08384598646991336

# %% [markdown]
# Drop Duplicates.

# %%
name_basics = name_basics.drop_duplicates(subset=['primary_name'], keep=False,)

# %%
name_basics
# Out:
#             nconst                 primary_name  birth_year  death_year  \
# 334669   nm6950093  !'aru Ikhuisi Piet Berendse         NaN         NaN
# 480537   nm6750303                      $hutter         NaN         NaN
# 68747   nm10554376               'A.J.' Marriot         NaN         NaN
# 177430   nm2764095         'Atlas' Ramachandran         NaN         NaN
# 252452   nm5169037              'Atolomake Helu         NaN         NaN
# ...            ...                          ...         ...         ...
# 196669   nm1940028         Þórhallur Gunnarsson         NaN         NaN
# 276289   nm5352411        Þórhallur Þórhallsson         NaN         NaN
# 251954   nm4964487               Þórir Bragason         NaN         NaN
# 361353   nm8372002             Þórir Ingvarsson         NaN         NaN
# 490858   nm5232286         Þórður Aðalbjörnsson         NaN         NaN
#
#                       primary_profession  \
# 334669                               NaN
# 480537                             actor
# 68747               writer,miscellaneous
# 177430                    actor,director
# 252452                               NaN
# ...                                  ...
# 196669                    producer,actor
# 276289                      actor,writer
# 251954                          composer
# 361353  cinematographer,sound_department
# 490858                             actor
#
#                                known_for_titles
# 334669                                tt4245110
# 480537  tt4049298,tt1398426,tt2080374,tt1741273
# 68747                                       NaN
# 177430  tt3433162,tt1311658,tt2333760,tt0928194
# 252452                                tt1966622
# ...                                         ...
# 196669  tt9100536,tt6770148,tt7690774,tt5038858
# 276289  tt3505804,tt5711254,tt7893482,tt5497896
# 251954                                tt2316669
# 361353                                tt5977838
# 490858                                tt2343384
#
# [555783 rows x 6 columns]

# %%
print(name_basics.shape)
print(606648-555783)
# Out:
# (555783, 6)
# 50865

# %%
title_p.columns.str.replace(' ', '')
title_p.head()
# Out:
#       tconst  ordering     nconst  category       job        characters
# 0  tt0111414         1  nm0246005     actor       NaN       ["The Man"]
# 1  tt0111414         2  nm0398271  director       NaN               NaN
# 2  tt0111414         3  nm3739909  producer  producer               NaN
# 3  tt0323808        10  nm0059247    editor       NaN               NaN
# 4  tt0323808         1  nm3579312   actress       NaN  ["Beth Boothby"]

# %% [markdown]
# Check for null values in title principles.

# %%
title_p['nconst'].isna().sum()
# Out:
# 0

# %% [markdown]
# Sorting values in dataframe by nconst

# %%
title_p = title_p.sort_values(by=['nconst'])
title_p.head()
# Out:
#            tconst  ordering     nconst         category  job  \
# 263152  tt2053352         4  nm0000002  archive_footage  NaN
# 15288   tt1626811         4  nm0000002             self  NaN
# 223302  tt0858500         2  nm0000002          actress  NaN
# 252036  tt1368858         1  nm0000002          actress  NaN
# 229763  tt1714820         3  nm0000003  archive_footage  NaN
#
#                        characters
# 263152                ["Herself"]
# 15288   ["Herself - Interviewee"]
# 223302                    ["May"]
# 252036             ["Anne-Marie"]
# 229763                ["Herself"]

# %%
principals_dupes = title_p.loc[title_p.duplicated(subset=['nconst'],keep=False) == True]
principals_dupes.shape
# Out:
# (582339, 6)

# %% [markdown]
# Merging title principles and name basics into a single column.

# %%
principals_and_names = pd.merge(
    title_p,
    name_basics,
    how='inner',
    on ='nconst')
principals_and_names.head(30)
# Out:
#         tconst  ordering     nconst         category  job  \
# 0    tt2053352         4  nm0000002  archive_footage  NaN
# 1    tt1626811         4  nm0000002             self  NaN
# 2    tt0858500         2  nm0000002          actress  NaN
# 3    tt1368858         1  nm0000002          actress  NaN
# 4    tt1714820         3  nm0000003  archive_footage  NaN
# 5    tt2004245         1  nm0000003  archive_footage  NaN
# 6    tt4323536         3  nm0000003  archive_footage  NaN
# 7    tt2327430         2  nm0000005  archive_footage  NaN
# 8    tt2056773         1  nm0000005  archive_footage  NaN
# 9    tt9209768         1  nm0000005             self  NaN
# 10   tt8385142         2  nm0000005  archive_footage  NaN
# 11   tt6109168         1  nm0000005  archive_footage  NaN
# 12   tt1648206         2  nm0000006  archive_footage  NaN
# 13   tt4621016         1  nm0000006  archive_footage  NaN
# 14   tt2388426         1  nm0000006  archive_footage  NaN
# 15   tt4926886         1  nm0000006  archive_footage  NaN
# 16   tt7215006         3  nm0000007  archive_footage  NaN
# 17   tt4145178         1  nm0000008  archive_footage  NaN
# 18   tt2004245         2  nm0000008  archive_footage  NaN
# 19   tt5084458         1  nm0000010  archive_footage  NaN
# 20   tt2246829         6  nm0000016         composer  NaN
# 21   tt3751664         1  nm0000019  archive_footage  NaN
# 22   tt2074373         2  nm0000019  archive_footage  NaN
# 23   tt2004245         9  nm0000019  archive_footage  NaN
# 24   tt3215046         3  nm0000019  archive_footage  NaN
# 25   tt3774110         9  nm0000022  archive_footage  NaN
# 26  tt10267396         1  nm0000023  archive_footage  NaN
# 27   tt3169638         2  nm0000026  archive_footage  NaN
# 28   tt4926886         2  nm0000026  archive_footage  NaN
# 29   tt7171150         1  nm0000026             self  NaN
#
#                    characters      primary_name  birth_year  death_year  \
# 0                 ["Herself"]     Lauren Bacall      1924.0      2014.0
# 1   ["Herself - Interviewee"]     Lauren Bacall      1924.0      2014.0
# 2                     ["May"]     Lauren Bacall      1924.0      2014.0
# 3              ["Anne-Marie"]     Lauren Bacall      1924.0      2014.0
# 4                 ["Herself"]   Brigitte Bardot      1934.0         NaN
# 5                 ["Herself"]   Brigitte Bardot      1934.0         NaN
# 6                 ["Herself"]   Brigitte Bardot      1934.0         NaN
# 7                 ["Himself"]    Ingmar Bergman      1918.0      2007.0
# 8                         NaN    Ingmar Bergman      1918.0      2007.0
# 9         ["Himself (voice)"]    Ingmar Bergman      1918.0      2007.0
# 10                ["Himself"]    Ingmar Bergman      1918.0      2007.0
# 11                ["Himself"]    Ingmar Bergman      1918.0      2007.0
# 12                ["Herself"]    Ingrid Bergman      1915.0      1982.0
# 13                ["Herself"]    Ingrid Bergman      1915.0      1982.0
# 14                ["Herself"]    Ingrid Bergman      1915.0      1982.0
# 15                ["Herself"]    Ingrid Bergman      1915.0      1982.0
# 16                ["Himself"]   Humphrey Bogart      1899.0      1957.0
# 17                ["Himself"]     Marlon Brando      1924.0      2004.0
# 18                ["Himself"]     Marlon Brando      1924.0      2004.0
# 19                ["Himself"]      James Cagney      1899.0      1986.0
# 20                        NaN   Georges Delerue      1925.0      1992.0
# 21                ["Himself"]  Federico Fellini      1920.0      1993.0
# 22                ["Himself"]  Federico Fellini      1920.0      1993.0
# 23                ["Himself"]  Federico Fellini      1920.0      1993.0
# 24                ["Himself"]  Federico Fellini      1920.0      1993.0
# 25                ["Himself"]       Clark Gable      1901.0      1960.0
# 26                ["Herself"]      Judy Garland      1922.0      1969.0
# 27                ["Himself"]        Cary Grant      1904.0      1986.0
# 28                ["Himself"]        Cary Grant      1904.0      1986.0
# 29                ["Himself"]        Cary Grant      1904.0      1986.0
#
#                       primary_profession  \
# 0                     actress,soundtrack
# 1                     actress,soundtrack
# 2                     actress,soundtrack
# 3                     actress,soundtrack
# 4            actress,soundtrack,producer
# 5            actress,soundtrack,producer
# 6            actress,soundtrack,producer
# 7                  writer,director,actor
# 8                  writer,director,actor
# 9                  writer,director,actor
# 10                 writer,director,actor
# 11                 writer,director,actor
# 12           actress,soundtrack,producer
# 13           actress,soundtrack,producer
# 14           actress,soundtrack,producer
# 15           actress,soundtrack,producer
# 16             actor,soundtrack,producer
# 17             actor,soundtrack,director
# 18             actor,soundtrack,director
# 19             actor,soundtrack,director
# 20  composer,soundtrack,music_department
# 21    writer,director,assistant_director
# 22    writer,director,assistant_director
# 23    writer,director,assistant_director
# 24    writer,director,assistant_director
# 25             actor,soundtrack,producer
# 26                    soundtrack,actress
# 27             actor,soundtrack,producer
# 28             actor,soundtrack,producer
# 29             actor,soundtrack,producer
#
#                            known_for_titles
# 0   tt0038355,tt0117057,tt0071877,tt0037382
# 1   tt0038355,tt0117057,tt0071877,tt0037382
# 2   tt0038355,tt0117057,tt0071877,tt0037382
# 3   tt0038355,tt0117057,tt0071877,tt0037382
# 4   tt0049189,tt0057345,tt0054452,tt0059956
# 5   tt0049189,tt0057345,tt0054452,tt0059956
# 6   tt0049189,tt0057345,tt0054452,tt0059956
# 7   tt0069467,tt0050986,tt0083922,tt0050976
# 8   tt0069467,tt0050986,tt0083922,tt0050976
# 9   tt0069467,tt0050986,tt0083922,tt0050976
# 10  tt0069467,tt0050986,tt0083922,tt0050976
# 11  tt0069467,tt0050986,tt0083922,tt0050976
# 12  tt0071877,tt0036855,tt0038109,tt0038787
# 13  tt0071877,tt0036855,tt0038109,tt0038787
# 14  tt0071877,tt0036855,tt0038109,tt0038787
# 15  tt0071877,tt0036855,tt0038109,tt0038787
# 16  tt0034583,tt0033870,tt0037382,tt0043265
# 17  tt0078788,tt0070849,tt0047296,tt0068646
# 18  tt0078788,tt0070849,tt0047296,tt0068646
# 19  tt0029870,tt0055256,tt0035575,tt0031867
# 20  tt0091763,tt0080610,tt0069946,tt0096320
# 21  tt0047528,tt0053779,tt0056801,tt0071129
# 22  tt0047528,tt0053779,tt0056801,tt0071129
# 23  tt0047528,tt0053779,tt0056801,tt0071129
# 24  tt0047528,tt0053779,tt0056801,tt0071129
# 25  tt0052278,tt0026752,tt0031381,tt0025316
# 26  tt0055031,tt0037059,tt0032138,tt0047522
# 27  tt0048728,tt0053125,tt0032599,tt0056923
# 28  tt0048728,tt0053125,tt0032599,tt0056923
# 29  tt0048728,tt0053125,tt0032599,tt0056923

# %% [markdown]
# Filter out the professions that are not actors.

# %%
actors = principals_and_names[principals_and_names["primary_profession"].str.contains('actor|actress', na=False)]

# %%
actors.head()
# Out:
#       tconst  ordering     nconst         category  job  \
# 0  tt2053352         4  nm0000002  archive_footage  NaN
# 1  tt1626811         4  nm0000002             self  NaN
# 2  tt0858500         2  nm0000002          actress  NaN
# 3  tt1368858         1  nm0000002          actress  NaN
# 4  tt1714820         3  nm0000003  archive_footage  NaN
#
#                   characters     primary_name  birth_year  death_year  \
# 0                ["Herself"]    Lauren Bacall      1924.0      2014.0
# 1  ["Herself - Interviewee"]    Lauren Bacall      1924.0      2014.0
# 2                    ["May"]    Lauren Bacall      1924.0      2014.0
# 3             ["Anne-Marie"]    Lauren Bacall      1924.0      2014.0
# 4                ["Herself"]  Brigitte Bardot      1934.0         NaN
#
#             primary_profession                         known_for_titles
# 0           actress,soundtrack  tt0038355,tt0117057,tt0071877,tt0037382
# 1           actress,soundtrack  tt0038355,tt0117057,tt0071877,tt0037382
# 2           actress,soundtrack  tt0038355,tt0117057,tt0071877,tt0037382
# 3           actress,soundtrack  tt0038355,tt0117057,tt0071877,tt0037382
# 4  actress,soundtrack,producer  tt0049189,tt0057345,tt0054452,tt0059956

# %% [markdown]
# Filter out birth years greater than 1939

# %%
 
actors = actors[actors['birth_year'] > 1939]
actors.sort_values(by=['birth_year'])
# Out:
#             tconst  ordering      nconst         category  job  \
# 136080   tt5644726         9   nm0661886            actor  NaN
# 23606    tt5329852         1   nm0033037            actor  NaN
# 169399   tt4030014         1   nm0871618            actor  NaN
# 6493     tt1436559         3   nm0000981            actor  NaN
# 23557    tt5440362         8   nm0032895             self  NaN
# ...            ...       ...         ...              ...  ...
# 762448   tt4100182         2   nm6446418            actor  NaN
# 220573  tt10360096         3  nm10708650          actress  NaN
# 201842   tt9392402         1  nm10306475          actress  NaN
# 201841   tt9396174         1  nm10306475          actress  NaN
# 873570   tt6023560         3   nm8405397  archive_footage  NaN
#
#                  characters      primary_name  birth_year  death_year  \
# 136080  ["Kim Byeong-deok"]  Geun-hyeong Park      1940.0         NaN
# 23606                   NaN   Humberto Arango      1940.0      2018.0
# 169399                  NaN       Alex Trebek      1940.0         NaN
# 6493            ["Bradley"]      James Brolin      1940.0         NaN
# 23557           ["Himself"]   Nobuyoshi Araki      1940.0         NaN
# ...                     ...               ...         ...         ...
# 762448            ["Guyus"]  Gaius Lee DuPree      2013.0         NaN
# 220573            ["Katie"]      Nayana Niter      2014.0         NaN
# 201842             ["Buny"]  Natalye Archiles      2014.0         NaN
# 201841           ["Monica"]  Natalye Archiles      2014.0         NaN
# 873570          ["Herself"]      Indiana Feek      2014.0         NaN
#
#                       primary_profession  \
# 136080                             actor
# 23606                              actor
# 169399                    producer,actor
# 6493             actor,producer,director
# 23557   director,actor,camera_department
# ...                                  ...
# 762448             actor,cinematographer
# 220573                           actress
# 201842                           actress
# 201841                           actress
# 873570                           actress
#
#                                known_for_titles
# 136080  tt0334024,tt0375137,tt3179566,tt0378695
# 23606   tt0089178,tt0073936,tt5373228,tt4786620
# 169399  tt0117723,tt0160127,tt0106179,tt0159881
# 6493    tt0070909,tt0077294,tt0078767,tt0181865
# 23557   tt0081662,tt0286737,tt0109059,tt0103316
# ...                                         ...
# 762448  tt4041788,tt3776720,tt4648810,tt4768296
# 220573                                      NaN
# 201842            tt9392402,tt6877772,tt9396174
# 201841            tt9392402,tt6877772,tt9396174
# 873570                      tt4569878,tt8347504
#
# [146376 rows x 11 columns]

# %% [markdown]
# Merge actors and their individual ratings.

# %%
actors_and_ratings = pd.merge(
    actors,
    ratings,
    how='inner',
    on ='tconst')
actors_and_ratings
# Out:
#            tconst  ordering     nconst         category  job  \
# 0       tt2451742         4  nm0000029  archive_footage  NaN
# 1       tt2451742         2  nm0376017             self  NaN
# 2       tt4591310         2  nm0000084          actress  NaN
# 3       tt4591310         1  nm0477209            actor  NaN
# 4       tt4591310         3  nm2682046            actor  NaN
# ...           ...       ...        ...              ...  ...
# 115025  tt8752420         5  nm9822023         director  NaN
# 115026  tt9800694         3  nm9828762            actor  NaN
# 115027  tt3588492         4  nm9836604          actress  NaN
# 115028  tt8478058         2  nm9879092            actor  NaN
# 115029  tt8622286         1  nm9936604            actor  NaN
#
#                                characters          primary_name  birth_year  \
# 0                             ["Herself"]     Margaux Hemingway      1954.0
# 1                             ["Herself"]        Joan Hemingway      1950.0
# 2       ["Baigujing","White-Boned Demon"]               Li Gong      1965.0
# 3            ["Sun Wukong","Monkey King"]            Aaron Kwok      1965.0
# 4                           ["Tang Seng"]         Shaofeng Feng      1978.0
# ...                                   ...                   ...         ...
# 115025                                NaN         Jorge Tudanca      1999.0
# 115026                                NaN  Temmuz Gürkan Karaca      1987.0
# 115027                         ["Serpil"]           Ebru Ozturk      1986.0
# 115028                   ["James Howard"]                  Sali      1948.0
# 115029                                NaN        Ujwal Adhikari      1999.0
#
#         death_year                 primary_profession  \
# 0           1996.0              actress,miscellaneous
# 1              NaN                     actress,writer
# 2              NaN                            actress
# 3              NaN  actor,soundtrack,music_department
# 4              NaN       actor,producer,miscellaneous
# ...            ...                                ...
# 115025         NaN              director,writer,actor
# 115026         NaN                              actor
# 115027         NaN                            actress
# 115028         NaN                              actor
# 115029         NaN             actor,casting_director
#
#                                known_for_titles  averagerating  numvotes
# 0       tt0077800,tt0102122,tt0074802,tt0110138            6.6       272
# 1       tt0159897,tt0197152,tt0073637,tt0159854            6.6       272
# 2       tt0101640,tt0397535,tt0430357,tt0473444            6.0      2587
# 3       tt4417522,tt0165499,tt0768114,tt1691832            6.0      2587
# 4       tt2176668,tt2102472,tt2992146,tt2909116            6.0      2587
# ...                                         ...            ...       ...
# 115025  tt9361888,tt8752420,tt8382210,tt9784954            8.4        10
# 115026  tt1795096,tt2247207,tt7932896,tt9800694            5.4         7
# 115027                                tt8412590            4.1       176
# 115028                                tt8478058            8.5         6
# 115029            tt8275366,tt8622286,tt8967956            6.4        13
#
# [115030 rows x 13 columns]

# %% [markdown]
# Clean the actors and ratings columns.

# %%
actors_and_ratings.columns.str.replace(' ', '')
actors_and_ratings.head()
# Out:
#       tconst  ordering     nconst         category  job  \
# 0  tt2451742         4  nm0000029  archive_footage  NaN
# 1  tt2451742         2  nm0376017             self  NaN
# 2  tt4591310         2  nm0000084          actress  NaN
# 3  tt4591310         1  nm0477209            actor  NaN
# 4  tt4591310         3  nm2682046            actor  NaN
#
#                           characters       primary_name  birth_year  \
# 0                        ["Herself"]  Margaux Hemingway      1954.0
# 1                        ["Herself"]     Joan Hemingway      1950.0
# 2  ["Baigujing","White-Boned Demon"]            Li Gong      1965.0
# 3       ["Sun Wukong","Monkey King"]         Aaron Kwok      1965.0
# 4                      ["Tang Seng"]      Shaofeng Feng      1978.0
#
#    death_year                 primary_profession  \
# 0      1996.0              actress,miscellaneous
# 1         NaN                     actress,writer
# 2         NaN                            actress
# 3         NaN  actor,soundtrack,music_department
# 4         NaN       actor,producer,miscellaneous
#
#                           known_for_titles  averagerating  numvotes
# 0  tt0077800,tt0102122,tt0074802,tt0110138            6.6       272
# 1  tt0159897,tt0197152,tt0073637,tt0159854            6.6       272
# 2  tt0101640,tt0397535,tt0430357,tt0473444            6.0      2587
# 3  tt4417522,tt0165499,tt0768114,tt1691832            6.0      2587
# 4  tt2176668,tt2102472,tt2992146,tt2909116            6.0      2587

# %% [markdown]
# Drop the columns that are not needed.

# %%
actors_and_ratings = actors_and_ratings.drop(['ordering', 'job', 'characters', 'death_year', 'known_for_titles'], axis=1)
actors_and_ratings
# Out:
#            tconst     nconst         category          primary_name  \
# 0       tt2451742  nm0000029  archive_footage     Margaux Hemingway
# 1       tt2451742  nm0376017             self        Joan Hemingway
# 2       tt4591310  nm0000084          actress               Li Gong
# 3       tt4591310  nm0477209            actor            Aaron Kwok
# 4       tt4591310  nm2682046            actor         Shaofeng Feng
# ...           ...        ...              ...                   ...
# 115025  tt8752420  nm9822023         director         Jorge Tudanca
# 115026  tt9800694  nm9828762            actor  Temmuz Gürkan Karaca
# 115027  tt3588492  nm9836604          actress           Ebru Ozturk
# 115028  tt8478058  nm9879092            actor                  Sali
# 115029  tt8622286  nm9936604            actor        Ujwal Adhikari
#
#         birth_year                 primary_profession  averagerating  numvotes
# 0           1954.0              actress,miscellaneous            6.6       272
# 1           1950.0                     actress,writer            6.6       272
# 2           1965.0                            actress            6.0      2587
# 3           1965.0  actor,soundtrack,music_department            6.0      2587
# 4           1978.0       actor,producer,miscellaneous            6.0      2587
# ...            ...                                ...            ...       ...
# 115025      1999.0              director,writer,actor            8.4        10
# 115026      1987.0                              actor            5.4         7
# 115027      1986.0                            actress            4.1       176
# 115028      1948.0                              actor            8.5         6
# 115029      1999.0             actor,casting_director            6.4        13
#
# [115030 rows x 8 columns]

# %% [markdown]
# Filter out rows that are do not have "actor" or "actress" in "category" column.

# %%
actors_and_ratings = actors_and_ratings[actors_and_ratings["category"].str.contains('actor|actress', na=False)]
actors_and_ratings
# Out:
#            tconst     nconst category          primary_name  birth_year  \
# 2       tt4591310  nm0000084  actress               Li Gong      1965.0
# 3       tt4591310  nm0477209    actor            Aaron Kwok      1965.0
# 4       tt4591310  nm2682046    actor         Shaofeng Feng      1978.0
# 5       tt4591310  nm3370295    actor         Shenyang Xiao      1981.0
# 6       tt1092634  nm0000084  actress               Li Gong      1965.0
# ...           ...        ...      ...                   ...         ...
# 115024  tt8262666  nm9758704  actress             Jamie Leo      1999.0
# 115026  tt9800694  nm9828762    actor  Temmuz Gürkan Karaca      1987.0
# 115027  tt3588492  nm9836604  actress           Ebru Ozturk      1986.0
# 115028  tt8478058  nm9879092    actor                  Sali      1948.0
# 115029  tt8622286  nm9936604    actor        Ujwal Adhikari      1999.0
#
#                        primary_profession  averagerating  numvotes
# 2                                 actress            6.0      2587
# 3       actor,soundtrack,music_department            6.0      2587
# 4            actor,producer,miscellaneous            6.0      2587
# 5                          actor,director            6.0      2587
# 6                                 actress            6.4      8662
# ...                                   ...            ...       ...
# 115024                            actress            9.1         8
# 115026                              actor            5.4         7
# 115027                            actress            4.1       176
# 115028                              actor            8.5         6
# 115029             actor,casting_director            6.4        13
#
# [92810 rows x 8 columns]

# %% [markdown]
# 1.Making a new variable that stores average rating mutiplied by their votes.
# 2.Sort values by ascending.

# %%
actors_and_ratings['popularity_&_rating'] = actors_and_ratings['averagerating'] * actors_and_ratings['numvotes']
actors_and_ratings.sort_values(by=['popularity_&_rating'],ascending=False)
# Out:
# <ipython-input-36-b3585c45e334>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   actors_and_ratings['popularity_&_rating'] = actors_and_ratings['averagerating'] * actors_and_ratings['numvotes']
#           tconst     nconst category          primary_name  birth_year  \
# 1470   tt1375666  nm0330687    actor  Joseph Gordon-Levitt      1981.0
# 1469   tt1375666  nm0000138    actor     Leonardo DiCaprio      1974.0
# 1471   tt1375666  nm0680983  actress            Ellen Page      1987.0
# 3385   tt1345836  nm0000198    actor           Gary Oldman      1958.0
# 3386   tt1345836  nm0000288    actor        Christian Bale      1974.0
# ...          ...        ...      ...                   ...         ...
# 79456  tt6792126  nm4153825    actor            Petr Batek      1972.0
# 43763  tt8446392  nm0129648  actress   Nathalie Caldonazzo      1969.0
# 79454  tt6792126  nm1551077    actor       Ladislav Ondrej      1991.0
# 79453  tt6792126  nm0603184  actress        Dana Morávková      1971.0
# 79455  tt6792126  nm2511348  actress         Anna Kulovaná      1981.0
#
#                         primary_profession  averagerating  numvotes  \
# 1470             actor,producer,soundtrack            8.8   1841066
# 1469                 actor,producer,writer            8.8   1841066
# 1471           actress,producer,soundtrack            8.8   1841066
# 3385             actor,soundtrack,producer            8.4   1387769
# 3386   actor,editorial_department,producer            8.4   1387769
# ...                                    ...            ...       ...
# 79456                                actor            1.0         5
# 43763                              actress            1.0         5
# 79454                                actor            1.0         5
# 79453     actress,soundtrack,miscellaneous            1.0         5
# 79455                              actress            1.0         5
#
#        popularity_&_rating
# 1470            16201380.8
# 1469            16201380.8
# 1471            16201380.8
# 3385            11657259.6
# 3386            11657259.6
# ...                    ...
# 79456                  5.0
# 43763                  5.0
# 79454                  5.0
# 79453                  5.0
# 79455                  5.0
#
# [92810 rows x 9 columns]

# %% [markdown]
# Drop columns that are not needed.

# %%
simple_actors_and_ratings = actors_and_ratings.drop(['tconst','nconst','category','birth_year','primary_profession','averagerating','numvotes'], axis=1)
simple_actors_and_ratings.sort_values(by=['popularity_&_rating'],ascending=False)
# Out:
#                primary_name  popularity_&_rating
# 1470   Joseph Gordon-Levitt           16201380.8
# 1469      Leonardo DiCaprio           16201380.8
# 1471             Ellen Page           16201380.8
# 3385            Gary Oldman           11657259.6
# 3386         Christian Bale           11657259.6
# ...                     ...                  ...
# 79456            Petr Batek                  5.0
# 43763   Nathalie Caldonazzo                  5.0
# 79454       Ladislav Ondrej                  5.0
# 79453        Dana Morávková                  5.0
# 79455         Anna Kulovaná                  5.0
#
# [92810 rows x 2 columns]

# %% [markdown]
# 1. Group primary name,mean, and count.
# 2. Find the mean of the popularity and reviews.

# %%
actors_ranking = simple_actors_and_ratings.groupby(by=['primary_name']).agg(['mean','count'],as_index=False)
actors_ranking = actors_ranking.rename(columns={'mean':'pop_and_reviews','count':'count'})
actors_ranking.columns = actors_ranking.columns.droplevel(0)
actors_ranking = actors_ranking.sort_values(by=['pop_and_reviews'],ascending=False)
actors_ranking
# Out:
#                      pop_and_reviews  count
# primary_name
# Leonardo DiCaprio       5.199703e+06     10
# Idina Menzel            3.877485e+06      1
# Robert Downey Jr.       3.751984e+06     13
# Lucy Davis              3.656452e+06      1
# Carrie Fisher           3.286611e+06      1
# ...                              ...    ...
# Yûichirô Hirose         6.000000e+00      1
# Nathalie Caldonazzo     5.000000e+00      1
# Petr Batek              5.000000e+00      1
# Ladislav Ondrej         5.000000e+00      1
# Anna Kulovaná           5.000000e+00      1
#
# [32556 rows x 2 columns]

# %%
pd.set_option('display.float_format', lambda x: '%.2f' % x)

# %% [markdown]
# List out the top 10

# %%
top_10 = actors_ranking.head(10)
top_10
# Out:
#                    pop_and_reviews  count
# primary_name
# Leonardo DiCaprio       5199703.07     10
# Idina Menzel            3877485.00      1
# Robert Downey Jr.       3751983.99     13
# Lucy Davis              3656452.50      1
# Carrie Fisher           3286611.30      1
# Daniel Kaluuya          3083649.80      1
# Donna Murphy            2857654.80      1
# Ben Hardy               2763728.00      1
# Orto Ignatiussen        2737371.35      2
# Alison Sudol            2667076.90      1

# %%
top_10
# Out:
#                    pop_and_reviews  count
# primary_name
# Leonardo DiCaprio       5199703.07     10
# Idina Menzel            3877485.00      1
# Robert Downey Jr.       3751983.99     13
# Lucy Davis              3656452.50      1
# Carrie Fisher           3286611.30      1
# Daniel Kaluuya          3083649.80      1
# Donna Murphy            2857654.80      1
# Ben Hardy               2763728.00      1
# Orto Ignatiussen        2737371.35      2
# Alison Sudol            2667076.90      1

# %% [markdown]
# #  2.Plot Data

# %%
from matplotlib import pyplot as plt
top_10['pop_and_reviews'].plot(kind="barh",figsize=(30, 20),fontsize=25)
plt.title("Top 10 Actors/Actresses by Ratings and Popularity",fontsize=30)
plt.ylabel("Pop and Reviews",fontsize=30)
plt.xlabel("Actors and Actresses",fontsize=30)

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
